# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nomes = pd.read_table('nomes.csv', sep=',')

# %%
nomes
# Out:
#                                         alternative_names classification  \
# 0       AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 1                                              ARAAO|ARAO              M
# 2                            AHARON|AROM|ARON|ARYON|HARON              M
# 3                                 ADA|ADAH|ADAR|ADHA|HADA              F
# 4                                                     NaN              M
# ...                                                   ...            ...
# 100782                                           MACILEIA              F
# 100783  GELINE|GILEINE|GLEINE|GLEINER|GLEYNE|JAELINE|J...              F
# 100784                                  DEMILTOM|DEMILTON              M
# 100785  ALIVIA|ELIVIA|EULIVIA|HOLIVIA|LEIVIA|LIIVIA|LI...              F
# 100786                                             FABSON              M
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# ...

# %%
#retorna quantos dados nulos existem por coluna
nomes.isnull().sum()
# Out:
# alternative_names    30042
# classification           0
# first_name               0
# frequency_female     40303
# frequency_male       49855
# frequency_total          0
# frequency_group          0
# group_name               0
# ratio                    0
# dtype: int64

# %%
#retornando apenas as linhas que possuem alguma coluna com dado nulo
nomes[nomes.isnull().T.any()]
# Out:
#                                         alternative_names classification  \
# 0       AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 1                                              ARAAO|ARAO              M
# 2                            AHARON|AROM|ARON|ARYON|HARON              M
# 3                                 ADA|ADAH|ADAR|ADHA|HADA              F
# 4                                                     NaN              M
# ...                                                   ...            ...
# 100782                                           MACILEIA              F
# 100783  GELINE|GILEINE|GLEINE|GLEINER|GLEYNE|JAELINE|J...              F
# 100784                                  DEMILTOM|DEMILTON              M
# 100785  ALIVIA|ELIVIA|EULIVIA|HOLIVIA|LEIVIA|LIIVIA|LI...              F
# 100786                                             FABSON              M
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# ...

# %%
#Retornar linhas que possuem dados nulo
nomes[nomes.alternative_names.isnull()]
# Out:
#       alternative_names classification  first_name  frequency_female  \
# 4                   NaN              M       ABADE               NaN
# 6                   NaN              F      ABADIA            7438.0
# 7                   NaN              M     ABADIAS              45.0
# 8                   NaN              M      ABADIO               NaN
# 10                  NaN              M         ABD               NaN
# ...                 ...            ...         ...               ...
# 85831               NaN              F  ZULMERINDA             146.0
# 85839               NaN              F     ZUMILDE              33.0
# 85841               NaN              M      ZUMIRO               NaN
# 85846               NaN              F      ZUNIRA             139.0
# 85850               NaN              F      ZURENE              32.0
#
#        frequency_male  frequency_total  frequency_group  group_name     ratio
# ...

# %%
#Substitui apenas os valores nulos de nome por 'Sem alternativa'
nomes.loc[nomes.alternative_names.isnull(),'alternative_names'] = 'Sem alternativa'

# %%
#Conferindo se os nulos foram trocados por 'Sem alternativa'
nomes[nomes.alternative_names == 'Sem alternativa']
# Out:
#       alternative_names classification  first_name  frequency_female  \
# 4       Sem alternativa              M       ABADE               NaN
# 6       Sem alternativa              F      ABADIA            7438.0
# 7       Sem alternativa              M     ABADIAS              45.0
# 8       Sem alternativa              M      ABADIO               NaN
# 10      Sem alternativa              M         ABD               NaN
# ...                 ...            ...         ...               ...
# 85831   Sem alternativa              F  ZULMERINDA             146.0
# 85839   Sem alternativa              F     ZUMILDE              33.0
# 85841   Sem alternativa              M      ZUMIRO               NaN
# 85846   Sem alternativa              F      ZUNIRA             139.0
# 85850   Sem alternativa              F      ZURENE              32.0
#
#        frequency_male  frequency_total  frequency_group  group_name     ratio
# ...

# %%
#Retornar linhas que possuem dados nulo
nomes[nomes.frequency_female.isnull()]
# Out:
#                               alternative_names classification first_name  \
# 1                                    ARAAO|ARAO              M      AARAO
# 2                  AHARON|AROM|ARON|ARYON|HARON              M      AARON
# 4                               Sem alternativa              M      ABADE
# 5                                        ABADIR              M      ABADI
# 8                               Sem alternativa              M     ABADIO
# ...                                         ...            ...        ...
# 100765  GUAN|JHUAN|JHUANN|JUAM|JUAN|JUANN|JUHAN              M      JHUAM
# 100770                                   GARCEZ              M     GARCES
# 100773                             NAHUAN|NAUAN              M      NAUAM
# 100784                        DEMILTOM|DEMILTON              M  DEMAILTON
# 100786                                   FABSON              M     FADSON
#
#         frequency_female  frequency_male  frequency_total  frequency_group  \
# ...

# %%
#Substitui apenas os valores nulos de nome por '0'
#nomes.loc[nomes.frequency_female.isnull(),'frequency_female'] = '0'

# %%
#Conferindo se os nulos foram trocados por '0'
nomes[nomes.frequency_female == '0']
# Out:
# Empty DataFrame
# Columns: [alternative_names, classification, first_name, frequency_female, frequency_male, frequency_total, frequency_group, group_name, ratio]
# Index: []

# %%
#Retornar linhas que possuem dados nulo
nomes[nomes.frequency_male.isnull()]
# Out:
#                                         alternative_names classification  \
# 0       AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 3                                 ADA|ADAH|ADAR|ADHA|HADA              F
# 11                                                   ADDA              F
# 47                                                 ADEGIL              F
# 48                                        ADEGAIR|ADEJAIR              F
# ...                                                   ...            ...
# 100780                                    FABIELI|FABIELY              F
# 100781                                  JOCICLEI|JOCICLEY              F
# 100782                                           MACILEIA              F
# 100783  GELINE|GILEINE|GLEINE|GLEINER|GLEYNE|JAELINE|J...              F
# 100785  ALIVIA|ELIVIA|EULIVIA|HOLIVIA|LEIVIA|LIIVIA|LI...              F
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# ...

# %%
#Substitui apenas os valores nulos de nome por '0'
#nomes.loc[nomes.frequency_male.isnull(),'frequency_male'] = '0'

# %%
#Conferindo se os nulos foram trocados por '0'
nomes[nomes.frequency_male == '0']
# Out:
# Empty DataFrame
# Columns: [alternative_names, classification, first_name, frequency_female, frequency_male, frequency_total, frequency_group, group_name, ratio]
# Index: []

# %%
# Retornar Os 30 nomes femininos mais utilizados
nomes.loc[:,['first_name','frequency_female', 'alternative_names']].sort_values('frequency_female', ascending=False).head(30)
# Out:
#       first_name  frequency_female  \
# 56936      MARIA        11694738.0
# 5370         ANA         3079729.0
# 29747  FRANCISCA          721637.0
# 6690     ANTONIA          588783.0
# 1792     ADRIANA          565621.0
# 47064    JULIANA          562589.0
# 56577     MARCIA          551855.0
# 28898   FERNANDA          531607.0
# 66633   PATRICIA          529446.0
# 4242       ALINE          509869.0
# 73063     SANDRA          479230.0
# 10408     CAMILA          469851.0
# 5097      AMANDA          464624.0
# 10134      BRUNA          460770.0
# 43158    JESSICA          456472.0
# 52347    LETICIA          434056.0
# 47058      JULIA          430067.0
# 54397    LUCIANA          429769.0
# 80941    VANESSA          417512.0
# 56964    MARIANA          381778.0
# 30127   GABRIELA          378807.0
# 81378       VERA          376202.0
# 82003    VITORIA          366797.0
# 50741    LARISSA          360523.0
# 12694    CLAUDIA          358175.0
# ...

# %%
# Retornar um grafico com Os 30 nomes femininos mais utilizados
grafico_female1 = nomes.loc[:,['first_name','frequency_female']].sort_values('frequency_female', ascending=False).head(30)

plt.figure(figsize=(13,5))
plt.bar(grafico_female1.first_name, grafico_female1.frequency_female)
plt.title('Os 30 nomes femininos mais utilizados')
plt.xticks(rotation=90)
plt.show()

# %%
# Retornar Os 30 nomes femininos menos utilizados
nomes.loc[:,['first_name','frequency_female', 'alternative_names']].sort_values('frequency_female').head(30)
# Out:
#         first_name  frequency_female  \
# 96210      ISABLLE              20.0
# 10533    CARISIANE              20.0
# 61869        NAUDE              20.0
# 27427    EULALIANA              20.0
# 77638      THAFINI              20.0
# 97586       ALMARA              20.0
# 99152    EMILLAINE              20.0
# 5015        ALZINI              20.0
# 93910       EISHLA              20.0
# 99154        MAIAA              20.0
# 50369       LAENES              20.0
# 77555      TERIANE              20.0
# 97576    OLINDAMIR              20.0
# 77546    TEREZILMA              20.0
# 27525    EUNICELIA              20.0
# 12588  CLAUDELICIA              20.0
# 77439       TENIZA              20.0
# 92162        REJNE              20.0
# 61945       NAYDES              20.0
# 93934       JILENA              20.0
# 77425       TENILA              20.0
# 77406      TELVIRA              20.0
# 5030      ALZIVANE              20.0
# 77396        TELMO              20.0
# ...

# %%
# Retornar um grafico com Os 30 nomes femininos mais utilizados
grafico_female2 = nomes.loc[:,['first_name','frequency_female']].sort_values('frequency_female').head(30)

plt.figure(figsize=(13,5))
plt.bar(grafico_female2.first_name, grafico_female2.frequency_female)
plt.title('Os 30 nomes femininos menos utilizados')
plt.xticks(rotation=90)
plt.show()

# %%
# Retornar Os 30 nomes  masculinos mais utilizados
nomes.loc[:,['first_name','frequency_male', 'alternative_names']].sort_values('frequency_male', ascending=False).head(30)
# Out:
#       first_name  frequency_male  \
# 45450       JOSE       5732508.0
# 43998       JOAO       2971935.0
# 6741     ANTONIO       2567494.0
# 29758  FRANCISCO       1765197.0
# 10671     CARLOS       1483121.0
# 66729      PAULO       1417907.0
# 66757      PEDRO       1213557.0
# 54324      LUCAS       1116818.0
# 55018       LUIZ       1102927.0
# 56775     MARCOS       1101126.0
# 54990       LUIS        931530.0
# 30126    GABRIEL        922744.0
# 67511     RAFAEL        814709.0
# 15630     DANIEL        706527.0
# 56556    MARCELO        690098.0
# 10169      BRUNO        663271.0
# 22401    EDUARDO        628539.0
# 28809     FELIPE        615924.0
# 67750   RAIMUNDO        611174.0
# 70393    RODRIGO        598825.0
# 56357     MANOEL        590924.0
# 58317     MATEUS        583962.0
# 5885       ANDRE        578975.0
# 28905   FERNANDO        551776.0
# 28540      FABIO        545581.0
# 52068   LEONARDO        544258.0
# 34544    GUSTAVO        537598.0
# ...

# %%
# Retornar um grafico com Os 30 nomes masculinos mais utilizados
grafico_male1 = nomes.loc[:,['first_name','frequency_male']].sort_values('frequency_male', ascending=False).head(30)

plt.figure(figsize=(13,5))
plt.bar(grafico_male1.first_name, grafico_male1.frequency_male)
plt.title('Os 30 nomes masculinos mais utilizados')
plt.xticks(rotation=90)
plt.show()

# %%
# Retornar Os 30 nomes  masculinos menos utilizados
nomes.loc[:,['first_name','frequency_male', 'alternative_names']].sort_values('frequency_male').head(30)
# Out:
#        first_name  frequency_male  \
# 85982       ELBET            20.0
# 11986      CIDONE            20.0
# 95286      KELIEL            20.0
# 33985        GOIS            20.0
# 95296     THAILOM            20.0
# 95309        MAXX            20.0
# 33975      GOIACI            20.0
# 11966     CIDINES            20.0
# 56804      MARDER            20.0
# 87026       IZAUR            20.0
# 33959  GLORIVALDO            20.0
# 1930       ADUILO            20.0
# 87012      VYTTOR            20.0
# 11943     CIDIANO            20.0
# 86987   CARLISSOM            20.0
# 95382      JULHOR            20.0
# 95383     ANTINHO            20.0
# 11935    CIDERLEY            20.0
# 57042  MARICLECIO            20.0
# 57171   MARILANDO            20.0
# 57279     MARILSA            20.0
# 57288    MARILUCE            20.0
# 57289    MARILUCI            20.0
# 56806      MARDES            20.0
# 16705    DEJAKSON            20.0
# 87081    NILDEMIR            20.0
# ...

# %%
# Retornar um grafico com Os 30 nomes masculinos menos utilizados
grafico_male2 = nomes.loc[:,['first_name','frequency_male']].sort_values('frequency_male').head(30)

plt.figure(figsize=(13,5))
plt.bar(grafico_male2.first_name, grafico_male2.frequency_male)
plt.title('Os 30 nomes masculinos menos utilizados')
plt.xticks(rotation=90)
plt.show()

# %%
nomes.loc[:,['first_name','frequency_male','frequency_female', 'frequency_total', 'classification', 'alternative_names']].sort_values('frequency_total', ascending=False).head(30)
# Out:
#       first_name  frequency_male  frequency_female  frequency_total  \
# 56936      MARIA         39391.0        11694738.0         11734129
# 45450       JOSE       5732508.0           22021.0          5754529
# 5370         ANA         10129.0         3079729.0          3089858
# 43998       JOAO       2971935.0           12184.0          2984119
# 6741     ANTONIO       2567494.0            8854.0          2576348
# 29758  FRANCISCO       1765197.0            7000.0          1772197
# 10671     CARLOS       1483121.0            6070.0          1489191
# 66729      PAULO       1417907.0            5355.0          1423262
# 66757      PEDRO       1213557.0            6048.0          1219605
# 54324      LUCAS       1116818.0           10492.0          1127310
# 55018       LUIZ       1102927.0            4865.0          1107792
# 56775     MARCOS       1101126.0            5039.0          1106165
# 54990       LUIS        931530.0            4375.0           935905
# ...

# %%
# Retornar um grafico com Os 30 nomes mais utilizados entre masculinos e femininos.
grafico_total = nomes.loc[:,['first_name','frequency_total']].sort_values('frequency_total', ascending=False).head(30)

plt.figure(figsize=(13,5))
plt.bar(grafico_total.first_name, grafico_total.frequency_total)
plt.title('Os 30 nomes mais utilizados entre masculinos e femininos')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
teste = pd.read_table('nomes.csv', sep=',')

# %%
teste
# Out:
#                                         alternative_names classification  \
# 0       AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 1                                              ARAAO|ARAO              M
# 2                            AHARON|AROM|ARON|ARYON|HARON              M
# 3                                 ADA|ADAH|ADAR|ADHA|HADA              F
# 4                                                     NaN              M
# ...                                                   ...            ...
# 100782                                           MACILEIA              F
# 100783  GELINE|GILEINE|GLEINE|GLEINER|GLEYNE|JAELINE|J...              F
# 100784                                  DEMILTOM|DEMILTON              M
# 100785  ALIVIA|ELIVIA|EULIVIA|HOLIVIA|LEIVIA|LIIVIA|LI...              F
# 100786                                             FABSON              M
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 teste.sort_values(ascending=False)
#
# File C:\atividade\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
teste.loc[:,['first_name','frequency_total', 'classification']].sort_values('frequency_total', ascending=False).head(20)
# Out:
#       first_name  frequency_total classification
# 56936      MARIA         11734129              F
# 45450       JOSE          5754529              M
# 5370         ANA          3089858              F
# 43998       JOAO          2984119              M
# 6741     ANTONIO          2576348              M
# 29758  FRANCISCO          1772197              M
# 10671     CARLOS          1489191              M
# 66729      PAULO          1423262              M
# 66757      PEDRO          1219605              M
# 54324      LUCAS          1127310              M
# 55018       LUIZ          1107792              M
# 56775     MARCOS          1106165              M
# 54990       LUIS           935905              M
# 30126    GABRIEL           932449              M
# 67511     RAFAEL           821638              M
# 29747  FRANCISCA           725642              F
# 15630     DANIEL           711338              M
# 56556    MARCELO           693215              M
# ...

# %%
teste.loc[:,['first_name','frequency_total']].sort_values('frequency_total').head(20)
# Out:
#         first_name  frequency_total
# 20887        EDEIL               20
# 6159     ANELANDIA               20
# 65156       OLVAIR               20
# 56424    MAQUIAVEL               20
# 56437    MARACILDA               20
# 45088        JONNH               20
# 81448    VERDULINO               20
# 41622       JANICO               20
# 69302        REZIA               20
# 17719      DESIANI               20
# 84880     YORHANNA               20
# 65177     OMENAIDE               20
# 69280       REYANE               20
# 1930        ADUILO               20
# 34484  GUILLERMINA               20
# 88333      KELINHA               20
# 19845        DOLMA               20
# 56506     MARCEILA               20
# 1917       ADSELMA               20
# 88346   JIVANILSOM               20

# %%
teste.loc[:].sort_values('frequency_total', ascending=False)
# Out:
#                                        alternative_names classification  \
# 56936  HMARIA|MAARIA|MARAI|MARAIR|MARAY|MARHIA|MARIAA...              F
# 45450                  GOSE|JHOSE|JOSEH|JOSER|JOZE|JOZER              M
# 5370   AANA|ANAA|ANAH|ANAR|ANNA|ANNAH|HANA|HANAH|HANN...              F
# 43998                                   GOAO|JHOAO|JOAAO              M
# 6741   AANTONIO|ANNTONIO|ANTHONIO|ANTONHIO|ANTONIHO|A...              M
# ...                                                  ...            ...
# 36276                                                NaN              F
# 98559       CELEUZA|CILEUSA|CILEUZA|CLEUSA|CLEUZA|KLEUSA              F
# 15269                                          DALCIONEI              M
# 79063  AELISSON|ALEISSON|ALEIXON|ALISSOM|ALISSON|ALIX...              M
# 44982                                                NaN              M
#
#       first_name  frequency_female  frequency_male  frequency_total  \
# ...

# %%
# Out:
#                                         alternative_names classification  \
# 0       AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 1                                              ARAAO|ARAO              M
# 2                            AHARON|AROM|ARON|ARYON|HARON              M
# 3                                 ADA|ADAH|ADAR|ADHA|HADA              F
# 4                                                     NaN              M
# ...                                                   ...            ...
# 100782                                           MACILEIA              F
# 100783  GELINE|GILEINE|GLEINE|GLEINER|GLEYNE|JAELINE|J...              F
# 100784                                  DEMILTOM|DEMILTON              M
# 100785  ALIVIA|ELIVIA|EULIVIA|HOLIVIA|LEIVIA|LIIVIA|LI...              F
# 100786                                             FABSON              M
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# ...
